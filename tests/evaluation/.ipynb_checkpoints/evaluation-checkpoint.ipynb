# %% [markdown]
# # Auswertung der ersten Messungen

# %%
import json
import glob
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

d = {
}

expected_results_input = "./../expectedResults.json"

folder = "./../testresults/*.json"

file_list = glob.glob(folder)

data_array = []

with open (expected_results_input) as f:
    expected_results = json.load(f)
    print(expected_results)
# Out:
# {'name': 'Erwartetete Testergebnisse der Testsuite', 'desprcition': '10 QPS, 120 Sekunden, 1200 Request, Transienete Störungen für  40s', 'testcases': [{'name': 'normal', 'description': 'Noramles Verhalten - Positivtestfall', 'response-count': {'min': 1200, 'max': 1200}, 'RetCodes': {'200': {'min': 1200, 'max': 1200}, '500': {'min': 0, 'max': 0}, '503': {'min': 0, 'max': 0}, 'Other': {'min': 0, 'max': 0}}, 'Percentiles': {'50': {'min': 0, 'max': 0.1}, '90': {'min': 0, 'max': 0.2}}}, {'name': 'perm-error', 'description': 'Permanente Fehler', 'response-count': {'min': 1200, 'max': 1200}, 'RetCodes': {'200': {'min': 0, 'max': 0}, '500': {'min': 0, 'max': 100, '__comment': '10 Sekunden (100 Anfragen) Erkennungszeit wird geduldet'}, '503': {'min': 1000, 'max': 1200}, 'Other': {'min': 0, 'max': 0}}, 'Percentiles': {'50': {'min': 0, 'max': 0.1}, '90': {'min': 0, 'max': 0.2}}}]}

# %%
    
for file in file_list:
    with open(file) as f:
      json_data = json.load(f)
    row_dataframe = pd.json_normalize(json_data)
    percentiles_dataframe = pd.json_normalize(json_data['DurationHistogram']['Percentiles'])
    
    if "ErrorsDurationHistogram" in json_data:
        if json_data["ErrorsDurationHistogram"]["Count"] != 0:
            errors_percentiles_dataframe = pd.json_normalize(json_data['ErrorsDurationHistogram']['Percentiles'])
            row_dataframe['Errors50Percentile'] = errors_percentiles_dataframe[errors_percentiles_dataframe["Percentile"] == 50.0]['Value'] 
     #       row_dataframe['Erros90Percentile'] = errors_percentiles_dataframe[errors_percentiles_dataframe["Percentile"] > 90.0]['Value']

    row_dataframe['90Percentile'] = percentiles_dataframe.loc[3]['Value']
    row_dataframe['50Percentile'] = percentiles_dataframe[percentiles_dataframe["Percentile"] == 50.0]['Value']
   
    data_array.append(row_dataframe)

data = pd.concat(data_array, ignore_index=True)


#row_dataframe["TotalResponses"] = row_dataframe.filter(regex="RetCodes.*").sum(axis=1)
#Ausgabe der RetCodes der Istio-Testreihe
#data[data['Labels'].str.contains("-i-")].filter(regex="Label|RetCodes.*|50Percentile")

#Ausgabe der RetCodes der Traefik-Testreihe
overload_df = data[data['Labels'].str.contains("trans-overload-t-")]
overload_df = overload_df.fillna(0.0)
overload_df['Labels'] = overload_df['Labels'].replace({'trans-overload-t-':'','with-config-traefik-cb':'traefik','with-r4j-cb':'r4j','without-cb':'none','with-default-traefik':'df-traefik'},regex=True)
overload_df.filter(regex="Label|RetCodes.*|DurationHistogram.Count|50Percentile|90Percentile")
percentiles_dataframe.loc[3]['Value']
# Out:
# 0.23571428571428554

# %%
N = overload_df.shape[0]

ind = np.arange(N)*10   # the x locations for the groups
width = 5       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()


p1 = ax.bar(ind, list(overload_df['RetCodes.200']), width, label='RetCode 200')
p2 = ax.bar(ind, list(overload_df['RetCodes.503']), width, list(overload_df['RetCodes.200']), label='RetCode 503')
p3 = ax.bar(ind, list(overload_df['RetCodes.500']), width, list(overload_df['RetCodes.503']), label='RetCode 500')

ax.axhline(0, color='grey', linewidth=0.8)
ax.set_ylabel('Anzahl')
ax.set_title('Vergleich der RetCodes')
ax.set_xticks(ind, labels=list(overload_df['Labels']))
ax.legend()

# Label with label_type 'center' instead of the default 'edge'
ax.bar_label(p1, label_type='center')
ax.bar_label(p2, label_type='center')
ax.bar_label(p3, label_type='center')

plt.show()

# %%
#see: https://matplotlib.org/stable/gallery/lines_bars_and_markers/barchart.html#sphx-glr-gallery-lines-bars-and-markers-barchart-py
labels = overload_df['Labels']
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, list(overload_df['50Percentile']*1000), width, label='50th')
rects2 = ax.bar(x + width/2, list(overload_df['Errors50Percentile']), width, label='Errors 50th')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Sekunden')
ax.set_title('Antwortzeiten')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %%
#Ausgabe der RetCodes der Traefik-Testreihe
relevant_testdate_df = data #data[data['StartTime'].str.contains("2022-06-30")]

relevant_testdate_df.filter(regex="Label|RetCodes.*|DurationHistogram.Count|50Percentile|StartTime").sort_values(by=['StartTime'])
relevant_testdate_df.to_csv("rohdaten.csv")

# %% [markdown]
# ## Auswertung - Normales Verhalten

# %%
normal_df = relevant_testdate_df[relevant_testdate_df['Labels'].str.contains("normal")]
normal_df = normal_df.fillna(0.0)
#normal_df['Labels'] = normal_df['Labels'].replace({'normal':'','with-config-traefik-cb':'traefik','with-r4j-cb':'r4j','without-cb':'none','with-default-traefik':'df-traefik'},regex=True)
normal_df.filter(regex="Label|RetCodes.*|DurationHistogram.Count|50Percentile")
# Out:
#                               Labels  DurationHistogram.Count  \
# 16     normal-t-with-default-traefik                     1200
# 20                normal-r4j-nfa-all                     1200
# 22        normal-t-traefik-3-avg-res                     1200
# 23                  normal-r4j-nfa-4                     1200
# 24         normal-t-traefik-4-90-res                     1200
# 26                 normal-without-cb                     1200
# 28           normal-istio3-maxPenReq                     1200
# 43                  normal-r4j-nfa-2                     1200
# 51              normal-istio2-maxReq                      688
# 53   normal-t-traefik-2-err-duration                     1200
# 65            normal-t-traefik-4-all                     1200
# 77               normal-t-without-cb                     1200
# 78                normal-istio5-both                     1200
# 80                normal-r4j-default                     1200
# 82                  normal-r4j-nfa-3                     1200
# 90              normal-istio4-maxCon                     1200
# 104    normal-t-traefik-1-consErrors                     1200
# 114         normal-istio1-consErrors                     1200
# 132             normal-istio4-maxCon                     1200
# 133                 normal-r4j-nfa-1                     1200
#
#      ErrorsDurationHistogram.Count  RetCodes.200  RetCodes.503  \
# 16                               0        1200.0           0.0
# 20                               0        1200.0           0.0
# 22                               0        1200.0           0.0
# 23                               0        1200.0           0.0
# 24                               0        1200.0           0.0
# 26                               0        1200.0           0.0
# 28                               0        1200.0           0.0
# 43                               0        1200.0           0.0
# 51                             342         346.0         342.0
# 53                               0        1200.0           0.0
# 65                               0        1200.0           0.0
# 77                               0        1200.0           0.0
# 78                             598         602.0         598.0
# 80                               0        1200.0           0.0
# 82                               0        1200.0           0.0
# 90                               0        1200.0           0.0
# 104                              0        1200.0           0.0
# 114                              0        1200.0           0.0
# 132                              0        1200.0           0.0
# 133                              0        1200.0           0.0
#
#      Errors50Percentile  50Percentile  RetCodes.-1  RetCodes.500
# 16             0.000000      0.029184          0.0           0.0
# 20             0.000000      0.041971          0.0           0.0
# 22             0.000000      0.028292          0.0           0.0
# 23             0.000000      0.041651          0.0           0.0
# 24             0.000000      0.028306          0.0           0.0
# 26             0.000000      0.058316          0.0           0.0
# 28             0.000000      0.031928          0.0           0.0
# 43             0.000000      0.049727          0.0           0.0
# 51             0.007273      0.018759          0.0           0.0
# 53             0.000000      0.028465          0.0           0.0
# 65             0.000000      0.033920          0.0           0.0
# 77             0.000000      0.034291          0.0           0.0
# 78             0.007500      0.020000          0.0           0.0
# 80             0.000000      0.040368          0.0           0.0
# 82             0.000000      0.039439          0.0           0.0
# 90             0.000000      0.040742          0.0           0.0
# 104            0.000000      0.035776          0.0           0.0
# 114            0.000000      0.035345          0.0           0.0
# 132            0.000000      0.032548          0.0           0.0
# 133            0.000000      0.042745          0.0           0.0

# %% [markdown]
# ## Auswertung - Permanente Fehler
#
# Testskript: Fehler im Testskript bei R4J, ist korrigiert, Testläufe müssen nachgeholt werden

# %%
perm_error_df = relevant_testdate_df[relevant_testdate_df['Labels'].str.contains("perm-error")]
perm_error_df = perm_error_df.fillna(0.0)
perm_error_df.filter(regex="Label|RetCodes.*|DurationHistogram.Count|50Percentile|90Percentile")
# Out:
#                                   Labels  DurationHistogram.Count  \
# 7      perm-error-t-traefik-1-consErrors                     1200
# 11                perm-error-r4j-nfa-all                     1200
# 18        perm-error-t-traefik-3-avg-res                     1200
# 27           perm-error-istio3-maxPenReq                     1200
# 30                  perm-error-r4j-nfa-4                     1200
# 42                perm-error-istio5-both                     1200
# 48                 perm-error-without-cb                     1200
# 52               perm-error-t-without-cb                     1200
# 64                perm-error-r4j-default                     1200
# 76                  perm-error-r4j-nfa-3                     1200
# 83              perm-error-istio4-maxCon                     1200
# 84              perm-error-istio4-maxCon                     1200
# 85            perm-error-t-traefik-4-all                     1200
# 87                  perm-error-r4j-nfa-1                     1200
# 93          perm-error-istio1-consErrors                     1200
# 96   perm-error-t-traefik-2-err-duration                     1200
# 97     perm-error-t-with-default-traefik                     1200
# 101             perm-error-istio2-maxReq                     1200
# 122        perm-error-t-traefik-4-90-res                     1200
# 124                 perm-error-r4j-nfa-2                     1200
#
#      ErrorsDurationHistogram.Count  RetCodes.200  RetCodes.503  \
# 7                             1200           0.0           0.0
# 11                            1200           0.0        1178.0
# 18                            1200           0.0           0.0
# 27                            1200           0.0           0.0
# 30                            1200           0.0        1178.0
# 42                            1200           0.0        1189.0
# 48                            1200           0.0           0.0
# 52                            1200           0.0           0.0
# 64                            1200           0.0        1094.0
# 76                            1200           0.0        1174.0
# 83                            1200           0.0           0.0
# 84                            1200           0.0           0.0
# 85                            1200           0.0        1183.0
# 87                            1200           0.0        1175.0
# 93                            1200           0.0        1180.0
# 96                            1200           0.0        1181.0
# 97                            1200           0.0           0.0
# 101                           1200           0.0         590.0
# 122                           1200           0.0           0.0
# 124                           1200           0.0        1174.0
#
#      Errors50Percentile  90Percentile  50Percentile  RetCodes.-1  RetCodes.500
# 7              0.015937      0.120000      0.015937          0.0        1200.0
# 11             0.077602      0.176000      0.077602          0.0          22.0
# 18             0.013747      0.098571      0.013747          0.0        1200.0
# 27             0.014548      0.030000      0.014548          0.0        1200.0
# 30             0.080843      0.200000      0.080843          0.0          22.0
# 42             0.006423      0.017500      0.006423          0.0          11.0
# 48             0.016435      0.077500      0.016435          0.0        1200.0
# 52             0.009394      0.065000      0.009394          0.0        1200.0
# 64             0.092645      0.583333      0.092645          0.0         106.0
# 76             0.076812      0.325000      0.076812          0.0          26.0
# 83             0.018492      0.260000      0.018492          0.0        1200.0
# 84             0.015227      0.038846      0.015227          0.0        1200.0
# 85             0.006340      0.021818      0.006340          0.0          17.0
# 87             0.088500      0.316667      0.088500          0.0          25.0
# 93             0.006932      0.037500      0.006932          0.0          20.0
# 96             0.006344      0.017091      0.006344          0.0          19.0
# 97             0.014378      0.125000      0.014378          0.0        1200.0
# 101            0.012567      0.052500      0.012567          0.0         610.0
# 122            0.012760      0.083333      0.012760          0.0        1200.0
# 124            0.084052      0.295000      0.084052          0.0          26.0

# %% [markdown]
# ## Auswertung - Permanete Überlast
#
# Testskript: läuft, wie erwartet
# Testläufe: Testlaufe ohne CB hat nicht stattgefunden

# %%
perm_overload_df = relevant_testdate_df[relevant_testdate_df['Labels'].str.contains("perm-overload")]
perm_overload_df =perm_overload_df.fillna(0.0)
perm_overload_df.filter(regex="Label|RetCodes.*|DurationHistogram.Count|50Percentile")
# Out:
#                                      Labels  DurationHistogram.Count  \
# 1                   perm-overload-r4j-nfa-3                     1200
# 3                  perm-overload-without-cb                      411
# 4                   perm-overload-r4j-nfa-1                     1200
# 8               perm-overload-istio2-maxReq                     1173
# 9             perm-overload-t-traefik-4-all                     1200
# 32               perm-overload-t-without-cb                      512
# 34                  perm-overload-r4j-nfa-4                     1200
# 41   perm-overload-t-traefik-2-err-duration                      589
# 63                perm-overload-r4j-default                     1200
# 86        perm-overload-t-traefik-3-avg-res                     1200
# 91                perm-overload-r4j-nfa-all                     1200
# 92          perm-overload-istio1-consErrors                      329
# 99           perm-overload-istio3-maxPenReq                      421
# 103             perm-overload-istio4-maxCon                      521
# 105    perm-overload-t-traefik-1-consErrors                      491
# 108        perm-overload-t-traefik-4-90-res                     1200
# 113               perm-overload-istio5-both                     1200
# 118                 perm-overload-r4j-nfa-2                     1200
# 131    perm-overload-t-with-default-traefik                      546
#
#      ErrorsDurationHistogram.Count  RetCodes.200  RetCodes.503  \
# 1                             1183          17.0        1182.0
# 3                                6         405.0           0.0
# 4                             1198           2.0        1196.0
# 8                              786         387.0         785.0
# 9                             1183          17.0        1183.0
# 32                               0         512.0           0.0
# 34                            1173          27.0        1173.0
# 41                              40         549.0          40.0
# 63                            1198           2.0        1186.0
# 86                            1011         189.0        1011.0
# 91                            1195           5.0        1195.0
# 92                              13         316.0           0.0
# 99                              10         411.0           0.0
# 103                              0         521.0           0.0
# 105                              0         491.0           0.0
# 108                           1141          59.0        1141.0
# 113                           1070         130.0        1070.0
# 118                           1200           0.0        1200.0
# 131                              0         546.0           0.0
#
#      Errors50Percentile  50Percentile  RetCodes.-1  RetCodes.500
# 1              0.073624      0.074101          1.0           0.0
# 3              5.282018      0.988816          6.0           0.0
# 4              0.077572      0.077630          2.0           0.0
# 8              0.005500      0.012478          1.0           0.0
# 9              0.005732      0.005809          0.0           0.0
# 32             0.000000      0.905607          0.0           0.0
# 34             0.079431      0.080278          0.0           0.0
# 41             0.003889      0.841797          0.0           0.0
# 63             0.092185      0.092269         12.0           0.0
# 86             0.006098      0.007195          0.0           0.0
# 91             0.080027      0.080163          0.0           0.0
# 92             3.916858      1.418317         13.0           0.0
# 99             3.801117      0.983108         10.0           0.0
# 103            0.000000      0.918148          0.0           0.0
# 105            0.000000      0.931771          0.0           0.0
# 108            0.005701      0.005924          0.0           0.0
# 113            0.006036      0.006627          0.0           0.0
# 118            0.082500      0.082500          0.0           0.0
# 131            0.000000      0.891379          0.0           0.0

# %% [markdown]
# ## Auswertung - Transiente Fehler
# Testskript: läuft
# Testläufe: Abgebrochene / Falsche Testfälle dabei (Date-Problem)

# %%
trans_error_df = relevant_testdate_df[relevant_testdate_df['Labels'].str.contains("trans-error")]
trans_error_df = trans_error_df.fillna(0.0)
trans_error_df.filter(regex="Label|RetCodes.*|DurationHistogram.Count|50Percentile")
# Out:
#                                    Labels  DurationHistogram.Count  \
# 10              trans-error-istio4-maxCon                     1200
# 25                trans-error-r4j-nfa-all                     1200
# 35   trans-error-t-traefik-2-err-duration                     1200
# 39                trans-error-r4j-default                     1200
# 44               trans-error-t-without-cb                     1200
# 49                  trans-error-r4j-nfa-2                     1200
# 50                  trans-error-r4j-nfa-4                     1200
# 58              trans-error-istio2-maxReq                     1200
# 59            trans-error-t-traefik-4-all                     1200
# 60     trans-error-t-with-default-traefik                     1200
# 67                  trans-error-r4j-nfa-1                     1200
# 70                  trans-error-r4j-nfa-3                     1200
# 79     trans-error-t-traefik-1-consErrors                     1200
# 100        trans-error-t-traefik-4-90-res                     1200
# 117               trans-error-istio5-both                     1200
# 119                trans-error-without-cb                     1200
# 121       trans-error-t-traefik-3-avg-res                     1200
# 126         trans-error-istio1-consErrors                     1200
# 128          trans-error-istio3-maxPenReq                     1200
#
#      ErrorsDurationHistogram.Count  RetCodes.200  RetCodes.503  \
# 10                             400         800.0           0.0
# 25                             648         552.0         595.0
# 35                             436         764.0         378.0
# 39                             648         552.0         598.0
# 44                             400         800.0           0.0
# 49                             648         552.0         597.0
# 50                             648         552.0         598.0
# 58                             799         401.0         594.0
# 59                             603         597.0         541.0
# 60                             400         800.0           0.0
# 67                             608         592.0         595.0
# 70                             652         548.0         597.0
# 79                             400         800.0           0.0
# 100                            450         750.0          50.0
# 117                           1200           0.0        1191.0
# 119                            400         800.0           0.0
# 121                            450         750.0          50.0
# 126                            544         656.0         536.0
# 128                            400         800.0           0.0
#
#      Errors50Percentile  50Percentile  RetCodes.-1  RetCodes.500
# 10             0.017180      0.030720          0.0         400.0
# 25             0.068333      0.045156          0.0          53.0
# 35             0.007583      0.024714          0.0          58.0
# 39             0.074615      0.057094          0.0          50.0
# 44             0.009585      0.025128          0.0         400.0
# 49             0.071622      0.052650          0.0          51.0
# 50             0.075882      0.053333          0.0          50.0
# 58             0.009233      0.016178          0.0         205.0
# 59             0.006623      0.018143          0.0          62.0
# 60             0.013349      0.026240          0.0         400.0
# 67             0.067113      0.044702          0.0          13.0
# 70             0.065268      0.045797          0.0          55.0
# 79             0.014308      0.027062          0.0         400.0
# 100            0.011684      0.024454          0.0         400.0
# 117            0.006294      0.006294          0.0           9.0
# 119            0.015714      0.031100          0.0         400.0
# 121            0.012222      0.026831          0.0         400.0
# 126            0.006511      0.026301          0.0           8.0
# 128            0.015254      0.029937          0.0         400.0

# %% [markdown]
# ## Auswertung - Transiente Überlast

# %%
trans_overload_df = relevant_testdate_df[relevant_testdate_df['Labels'].str.contains("trans-overload")]
trans_overload_df = trans_overload_df.fillna(0.0)
trans_overload_df.filter(regex="Label|RetCodes.*|DurationHistogram.Count|50Percentile")
# Out:
#                                       Labels  DurationHistogram.Count  \
# 0             trans-overload-t-traefik-4-all                     1200
# 2               trans-overload-istio4-maxCon                     1200
# 12         trans-overload-t-traefik-4-90-res                     1200
# 13                trans-overload-r4j-nfa-all                     1200
# 29           trans-overload-istio3-maxPenReq                     1200
# 37          trans-overload-istio1-consErrors                     1200
# 40     trans-overload-t-with-default-traefik                     1200
# 46     trans-overload-t-traefik-1-consErrors                     1200
# 47                trans-overload-r4j-default                     1200
# 54              trans-overload-istio2-maxReq                     1200
# 66                  trans-overload-r4j-nfa-1                     1200
# 68        trans-overload-t-traefik-3-avg-res                     1200
# 69                trans-overload-istio5-both                     1200
# 71   trans-overload-t-traefik-2-err-duration                     1200
# 89                  trans-overload-r4j-nfa-2                     1200
# 111              trans-overload-t-without-cb                     1200
# 112                 trans-overload-r4j-nfa-4                     1200
# 115                 trans-overload-r4j-nfa-3                     1200
# 130                trans-overload-without-cb                     1200
#
#      ErrorsDurationHistogram.Count  RetCodes.200  RetCodes.503  \
# 0                              390         810.0         390.0
# 2                                0        1200.0           0.0
# 12                             390         810.0         390.0
# 13                               0        1200.0           0.0
# 29                               0        1200.0           0.0
# 37                               0        1200.0           0.0
# 40                               0        1200.0           0.0
# 46                               0        1200.0           0.0
# 47                               0        1200.0           0.0
# 54                             598         602.0         598.0
# 66                               0        1200.0           0.0
# 68                             271         929.0         271.0
# 69                             901         299.0         901.0
# 71                               0        1200.0           0.0
# 89                               0        1200.0           0.0
# 111                              0        1200.0           0.0
# 112                              0        1200.0           0.0
# 115                              0        1200.0           0.0
# 130                              0        1200.0           0.0
#
#      Errors50Percentile  50Percentile  RetCodes.-1  RetCodes.500
# 0              0.006725      0.026134          0.0           0.0
# 2              0.000000      0.040347          0.0           0.0
# 12             0.006095      0.025363          0.0           0.0
# 13             0.000000      0.042315          0.0           0.0
# 29             0.000000      0.037621          0.0           0.0
# 37             0.000000      0.038885          0.0           0.0
# 40             0.000000      0.041929          0.0           0.0
# 46             0.000000      0.040625          0.0           0.0
# 47             0.000000      0.042385          0.0           0.0
# 54             0.006460      0.019360          0.0           0.0
# 66             0.000000      0.045930          0.0           0.0
# 68             0.006938      0.030647          0.0           0.0
# 69             0.006147      0.008128          0.0           0.0
# 71             0.000000      0.033778          0.0           0.0
# 89             0.000000      0.048036          0.0           0.0
# 111            0.000000      0.039419          0.0           0.0
# 112            0.000000      0.043521          0.0           0.0
# 115            0.000000      0.037276          0.0           0.0
# 130            0.000000      0.055222          0.0           0.0

# %% [markdown]
# ## Auswertung - Sporadische Fehler

# %%
spor_error_df = relevant_testdate_df[relevant_testdate_df['Labels'].str.contains("spor-error")]
spor_error_df = spor_error_df.fillna(0.0)
spor_error_df.filter(regex="Label|RetCodes.*|DurationHistogram.Count|50Percentile")
# Out:
#                                   Labels  DurationHistogram.Count  \
# 5                   spor-error-r4j-nfa-2                     1200
# 6                 spor-error-istio5-both                     1200
# 17                spor-error-r4j-nfa-all                     1200
# 19        spor-error-t-traefik-3-avg-res                     1200
# 21   spor-error-t-traefik-2-err-duration                     1200
# 31              spor-error-istio4-maxCon                     1200
# 45     spor-error-t-traefik-1-consErrors                     1200
# 55         spor-error-t-traefik-4-90-res                     1200
# 57               spor-error-t-without-cb                     1200
# 61          spor-error-istio1-consErrors                     1200
# 88              spor-error-istio2-maxReq                     1200
# 102                spor-error-without-cb                     1200
# 107                 spor-error-r4j-nfa-1                     1200
# 109           spor-error-t-traefik-4-all                     1200
# 110    spor-error-t-with-default-traefik                     1200
# 116               spor-error-r4j-default                     1200
# 120                 spor-error-r4j-nfa-3                     1200
# 125                 spor-error-r4j-nfa-4                     1200
# 129          spor-error-istio3-maxPenReq                     1200
#
#      ErrorsDurationHistogram.Count  RetCodes.200  RetCodes.503  \
# 5                             1180          20.0        1155.0
# 6                             1193           7.0        1182.0
# 17                            1186          14.0        1174.0
# 19                             708         492.0           0.0
# 21                            1142          58.0        1053.0
# 31                             746         454.0           0.0
# 45                             721         479.0           0.0
# 55                             715         485.0           0.0
# 57                             710         490.0           0.0
# 61                            1183          17.0        1152.0
# 88                             953         247.0         586.0
# 102                            710         490.0           0.0
# 107                           1150          50.0        1069.0
# 109                           1146          54.0        1052.0
# 110                            753         447.0           0.0
# 116                           1170          30.0        1117.0
# 120                           1197           3.0        1181.0
# 125                           1189          11.0        1174.0
# 129                            717         483.0           0.0
#
#      Errors50Percentile  50Percentile  RetCodes.-1  RetCodes.500
# 5              0.072111      0.071608          0.0          25.0
# 6              0.006504      0.006532          0.0          11.0
# 17             0.069583      0.069358          0.0          12.0
# 19             0.011754      0.017407          0.0         708.0
# 21             0.005079      0.005310          0.0          89.0
# 31             0.013726      0.018140          0.0         746.0
# 45             0.011794      0.017759          0.0         721.0
# 55             0.010360      0.016615          0.0         715.0
# 57             0.007934      0.013231          0.0         710.0
# 61             0.005795      0.005856          0.0          31.0
# 88             0.010279      0.012707          0.0         367.0
# 102            0.015431      0.022406          0.0         710.0
# 107            0.067011      0.066243          0.0          81.0
# 109            0.005840      0.006062          0.0          94.0
# 110            0.012685      0.020000          0.0         753.0
# 116            0.071364      0.070899          0.0          53.0
# 120            0.065401      0.065330          0.0          16.0
# 125            0.072435      0.072344          0.0          15.0
# 129            0.014596      0.019600          0.0         717.0

# %% [markdown]
# ## Auswertung - Sporadische Überlast

# %%
spor_overload_df = relevant_testdate_df[relevant_testdate_df['Labels'].str.contains("spor-overload")]
spor_overload_df = spor_overload_df.fillna(0.0)
spor_overload_df.filter(regex="Label|RetCodes.*|DurationHistogram.Count|50Percentile")
# Out:
#                                      Labels  DurationHistogram.Count  \
# 14                 spor-overload-without-cb                     1200
# 15          spor-overload-istio1-consErrors                     1200
# 33         spor-overload-t-traefik-4-90-res                     1200
# 36        spor-overload-t-traefik-3-avg-res                     1200
# 38     spor-overload-t-traefik-1-consErrors                     1200
# 56                  spor-overload-r4j-nfa-1                     1200
# 62                  spor-overload-r4j-nfa-2                     1200
# 72                  spor-overload-r4j-nfa-4                     1200
# 73                spor-overload-r4j-nfa-all                     1200
# 74               spor-overload-t-without-cb                     1200
# 75   spor-overload-t-traefik-2-err-duration                     1200
# 81                  spor-overload-r4j-nfa-3                     1200
# 94            spor-overload-t-traefik-4-all                     1200
# 95     spor-overload-t-with-default-traefik                     1200
# 98              spor-overload-istio2-maxReq                     1200
# 106               spor-overload-r4j-default                     1200
# 123               spor-overload-istio5-both                     1200
# 127             spor-overload-istio4-maxCon                     1200
#
#      ErrorsDurationHistogram.Count  RetCodes.200  RetCodes.503  \
# 14                               0        1200.0           0.0
# 15                               0        1200.0           0.0
# 33                            1106          94.0        1106.0
# 36                             775         425.0         775.0
# 38                               0        1200.0           0.0
# 56                               0        1200.0           0.0
# 62                               0        1200.0           0.0
# 72                               0        1200.0           0.0
# 73                               0        1200.0           0.0
# 74                               0        1200.0           0.0
# 75                              50        1150.0          50.0
# 81                               0        1200.0           0.0
# 94                            1181          19.0        1181.0
# 95                               0        1200.0           0.0
# 98                             600         600.0         600.0
# 106                              1        1199.0           1.0
# 123                            844         356.0         844.0
# 127                              0        1200.0           0.0
#
#      Errors50Percentile  50Percentile  RetCodes.-1  RetCodes.500
# 14             0.000000      0.208636          0.0           0.0
# 15             0.000000      0.208445          0.0           0.0
# 33             0.005780      0.006227          0.0           0.0
# 36             0.006517      0.008902          0.0           0.0
# 38             0.000000      0.208297          0.0           0.0
# 56             0.000000      0.211148          0.0           0.0
# 62             0.000000      0.210148          0.0           0.0
# 72             0.000000      0.208239          0.0           0.0
# 73             0.000000      0.208997          0.0           0.0
# 74             0.000000      0.209655          0.0           0.0
# 75             0.005417      0.206747          0.0           0.0
# 81             0.000000      0.208003          0.0           0.0
# 94             0.006473      0.006559          0.0           0.0
# 95             0.000000      0.210925          0.0           0.0
# 98             0.006667      0.016842          0.0           0.0
# 106            0.066909      0.210067          0.0           0.0
# 123            0.005815      0.007933          0.0           0.0
# 127            0.000000      0.207871          0.0           0.0

# %% [markdown]
# ## Auswertung Diagramm

# %%
### Insert dataframe for diagramm here
diagramm_df = trans_error_df
diagramm_df['Labels'] = diagramm_df['Labels'].replace({'overload-':'','-with-config-traefik-cb':'traefik','-with-r4j-cb-':'r4j','-without-cb-':'none','with-default-traefik-':'df-traefik'},regex=True)
###


N = diagramm_df.shape[0]

ind = np.arange(N)   # the x locations for the groups
width = 0.5      # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()


p1 = ax.bar(ind, list(diagramm_df['RetCodes.200']), width, label='RetCode 200')
p2 = ax.bar(ind, list(diagramm_df['RetCodes.503']), width,list(diagramm_df['RetCodes.200']), label='RetCode 503')
p3 = ax.bar(ind, list(diagramm_df['RetCodes.500']), width, list(diagramm_df['RetCodes.503']), label='RetCode 500')

ax.axhline(0, color='grey', linewidth=0.8)
ax.set_ylabel('Anzahl')
ax.set_title('Vergleich der RetCodes')
ax.set_xticks(ind, labels=list(diagramm_df['Labels']),rotation=90)
ax.legend()

# Label with label_type 'center' instead of the default 'edge'
ax.bar_label(p1, label_type='center')
ax.bar_label(p2, label_type='center')
ax.bar_label(p3, label_type='center')

fig.savefig("retcodes-export.pdf")
plt.show()

# %%
#see: https://matplotlib.org/stable/gallery/lines_bars_and_markers/barchart.html#sphx-glr-gallery-lines-bars-and-markers-barchart-py
labels = diagramm_df['Labels']
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

diagramm_df['50Percentile'] = np.round(diagramm_df['50Percentile']*1000)

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, list(diagramm_df['50Percentile']), width, label='50th')
rects2 = ax.bar(x + width/2, list(diagramm_df['Errors50Percentile']), width, label='Errors 50th')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Millisekunden')
ax.set_title('Antwortzeiten')
ax.set_xticks(x, labels, rotation=90)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %%
#plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
mpl.style.use('seaborn')
hdia_df = trans_error_df

y_pos = np.arange(len(hdia_df))

p1 = ax.barh(ind, list(hdia_df['RetCodes.200']), width, left=0, label='200',color="green")
p2 = ax.barh(ind, list(hdia_df['RetCodes.503']), width, left=list(hdia_df['RetCodes.200']), label='503', color="purple")
p3 = ax.barh(ind, list(hdia_df['RetCodes.500']), width, left=list(hdia_df['RetCodes.200']+hdia_df['RetCodes.503']), label='500', color="red")

ax.set_yticks(y_pos, labels=hdia_df['Labels'])
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Verteilung der Antworten je HTTP-Status')
ax.set_ylabel('Circuit-Breaker')
ax.set_title('Vergleich der ReturnCodes')

ax.bar_label(p1, label_type="center")
ax.bar_label(p2,label_type="center")
ax.bar_label(p3, label_type="center")

#ax.legend()

plt.show()

# %%
def exportRetCodeDiagramm(diagramm_df, filename, title):
    mpl.style.use('seaborn')
    plt.rcdefaults()
    mpl.rcParams.update({'figure.autolayout': True})
    
    N = diagramm_df.shape[0]
    ind = np.arange(N)   
    width = 0.8 
    
    fig, ax = plt.subplots()
    
    p1 = ax.barh(ind, list(diagramm_df['RetCodes.200']), width, left=0, label='200',color="green")
    p2 = ax.barh(ind, list(diagramm_df['RetCodes.503']), width, left=list(diagramm_df['RetCodes.200']), label='503', color="purple")
    p3 = ax.barh(ind, list(diagramm_df['RetCodes.500']), width, left=list(diagramm_df['RetCodes.200']+diagramm_df['RetCodes.503']), label='500', color="red")
    ax.set_yticks(y_pos, labels=hdia_df['Labels'])
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('Verteilung der Antworten je HTTP-Status')
    ax.set_ylabel('Circuit-Breaker')
    ax.set_title(title)
    
    ax.bar_label(p1, label_type="center")
    ax.bar_label(p2,label_type="center")
    ax.bar_label(p3, label_type="center")
    
    fig.savefig(filename)
    


normal_df['Labels'] = normal_df['Labels'].replace({'normal-':''},regex=True)
exportRetCodeDiagramm(normal_df, "evaluationresults/1-normal-retcodes.pdf","Normales Verhalten: HTTP-Status-Codes")

perm_error_df['Labels'] = perm_error_df['Labels'].replace({'perm-error-':''},regex=True)
exportRetCodeDiagramm(perm_error_df, "evaluationresults/2-perm-error-retcodes.pdf","Permanente Fehler: HTTP-Status-Codes")

perm_overload_df['Labels'] = perm_overload_df['Labels'].replace({'perm-overload-':''},regex=True)
exportRetCodeDiagramm(perm_overload_df, "evaluationresults/3-perm-overload-retcodes.pdf","Permanente Überlast: HTTP-Status-Codes")

trans_error_df['Labels'] = trans_error_df['Labels'].replace({'trans-error-':''},regex=True)
exportRetCodeDiagramm(trans_error_df, "evaluationresults/4-trans-error-retcodes.pdf","Transiente Fehler: HTTP-Status-Codes")

trans_overload_df['Labels'] = trans_overload_df['Labels'].replace({'trans-overload-':''},regex=True)
exportRetCodeDiagramm(trans_error_df, "evaluationresults/5-trans-overload-retcodes.pdf","Transiente Überlast: HTTP-Status-Codes")

spor_error_df['Labels'] = spor_error_df['Labels'].replace({'spor-error-':''},regex=True)
exportRetCodeDiagramm(trans_error_df, "evaluationresults/6-spor-error-retcodes.pdf","Sporadische Fehler: HTTP-Status-Codes")

spor_overload_df['Labels'] = spor_overload_df['Labels'].replace({'spor-overload-':''},regex=True)
exportRetCodeDiagramm(trans_error_df, "evaluationresults/7-spor-overload-retcodes.pdf","Sporadische Überlast: HTTP-Status-Codes")

# %%
def exportRespTimeDiagramm(diagramm_df, filename, title):
    ##Two
    #see: https://matplotlib.org/stable/gallery/lines_bars_and_markers/barchart.html#sphx-glr-gallery-lines-bars-and-markers-barchart-py
    labels = diagramm_df['Labels']
    location = np.arange(len(labels))  # the label locations
    width = 0.35  # the width of the bars

    diagramm_df['50Percentile'] = np.round(diagramm_df['50Percentile']*1000)
    diagramm_df['Errors50Percentile'] = np.round(diagramm_df['Errors50Percentile']*1000)

    fig, ax = plt.subplots()
    rects1 = ax.barh(location - width/2, list(diagramm_df['50Percentile']), width, label='50th')
    rects2 = ax.barh(location + width/2, list(diagramm_df['Errors50Percentile']), width, label='Errors 50th')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    #ax.set_xlabel('Millisekunden')
    #ax.set_title('Antwortzeiten')
    #ax.set_xticks(x, labels, rotation=90)
    #ax.legend()

    ax.bar_label(rects1, padding=3)
    ax.bar_label(rects2, padding=3)

    #fig.tight_layout()

    plt.show()
    
exportRespTimeDiagramm(normal_df, "evaluationresults/1-normal-resp-time.pdf","Normales Verhalten: Antwortzeiten")
